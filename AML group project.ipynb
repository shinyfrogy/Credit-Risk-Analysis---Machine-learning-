# %% [markdown]
# # BUAN 6341 Credit Risk Analysis Group Project
#
# Source of Data : https://www.kaggle.com/competitions/amex-default-prediction/data

# %% [markdown]
# # Import All Libraries

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Open Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# Unzip train_data.csv.zip and train_labels.csv.zip
import zipfile
import os

# Assuming the zip files are in the current working directory
with zipfile.ZipFile('drive/My Drive/AML group project/train_data.csv.zip', 'r') as zip_ref:
    zip_ref.extractall('train_data.csv')  # Extract to this directory

with zipfile.ZipFile('drive/My Drive/AML group project/train_labels.csv.zip', 'r') as zip_ref:
    zip_ref.extractall('train_labels.csv')  # Extract to this directory

# Verify the files have been extracted
print(os.listdir('train_data.csv'))
print(os.listdir('train_labels.csv'))

# %%
# extract 20% of observations from "train_labels.csv"
labels = pd.read_csv("path/to/train_labels.csv")
labels_sample = labels.sample(frac=0.2, random_state=42)
# merge the sample with "train_data.csv"

# %% [markdown]
# # Null Value

# %% [markdown]
# # One Hot Encoding

# %% [markdown]
# # Feature Selection
